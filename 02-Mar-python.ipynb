# %%
## Q No. 1 :
"""
Matplotlib is a python library used to create 2D graphs and plots by using python scripts.
It has a module named pyplot which makes things easy for plotting by providing feature to control line styles,
font properties, formatting axes etc.

Plot types :
plot(x, y)
scatter(x, y)
bar(x, height)
stem(x, y)
step(x, y)
"""
# Out:
# '\nMatplotlib is a python library used to create 2D graphs and plots by using python scripts.\nIt has a module named pyplot which makes things easy for plotting by providing feature to control line styles,\nfont properties, formatting axes etc.\n\nPlot types :\nplot(x, y)\nscatter(x, y)\nbar(x, height)\nstem(x, y)\nstep(x, y)\n'

# %%
## Q No. 2:
'''
Scatter plots are the graphs that present the relationship between two variables in a data-set. 
It represents data points on a two-dimensional plane or on a Cartesian system.
The independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis.
'''
# Out:
# '\nScatter plots are the graphs that present the relationship between two variables in a data-set. \nIt represents data points on a two-dimensional plane or on a Cartesian system.\nThe independent variable or attribute is plotted on the X-axis, while the dependent variable is plotted on the Y-axis.\n'

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.xlabel="x axis"
plt.ylabel="y axis"
plt.title=('title of the plot')

# %%
plt.scatter(x,y,c="red",marker="x")

# %%
## Q No. 3 :
'''
subplot() function adds subplot to a current figure at the specified grid position. 
It is similar to the subplots() function however unlike subplots() it adds one subplot at a time.
So to create multiple plots you will need several lines of code with the subplot() function.
Another drawback of the subplot function is that it deletes the preexisting plot on your figure. 
'''
# Out:
# '\nsubplot() function adds subplot to a current figure at the specified grid position. \nIt is similar to the subplots() function however unlike subplots() it adds one subplot at a time.\nSo to create multiple plots you will need several lines of code with the subplot() function.\nAnother drawback of the subplot function is that it deletes the preexisting plot on your figure. \n'

# %%
# plot 1
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,3, 1)
plt.plot(x,y)
# plot 2
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,3,2)
plt.plot(x,y)
## plot 3
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,3,3)
plt.plot(x,y)

# plot 4 
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,3,4)
plt.plot(x,y)

# %%
## Q No. 4 :
"""
The purpose of a bar graph is to convey relational information quickly in a visual manner. 
The bars display the value for a particular category of data.
The vertical axis on the left or right side of the bar graph is called the y-axis
"""
# Out:
# '\nThe purpose of a bar graph is to convey relational information quickly in a visual manner. \nThe bars display the value for a particular category of data.\nThe vertical axis on the left or right side of the bar graph is called the y-axis\n'

# %%
import matplotlib.pyplot as plt
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
## Q No. 5 :
'''
Box plots provide a quick visual summary of the variability of values in a dataset. 
They show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the dataset. 
Outliers can reveal mistakes or unusual occurrences in data.
'''
# Out:
# '\nBox plots provide a quick visual summary of the variability of values in a dataset. \nThey show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the dataset. \nOutliers can reveal mistakes or unusual occurrences in data.\n'

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data=[box1,box2]
fig=plt.figure(figsize=(6,5))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5d93f09f00>,
#   <matplotlib.lines.Line2D at 0x7f5d93f0ad10>,
#   <matplotlib.lines.Line2D at 0x7f5d93e14b20>,
#   <matplotlib.lines.Line2D at 0x7f5d93e17d30>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f5d93f0b190>,
#   <matplotlib.lines.Line2D at 0x7f5d93e159c0>,
#   <matplotlib.lines.Line2D at 0x7f5d93f4aec0>,
#   <matplotlib.lines.Line2D at 0x7f5d93f4b940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5d93f094b0>,
#   <matplotlib.lines.Line2D at 0x7f5d93e17640>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5d93e16170>,
#   <matplotlib.lines.Line2D at 0x7f5d93f4ba60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5d93e15750>,
#   <matplotlib.lines.Line2D at 0x7f5d93f28430>],
#  'means': []}
